# %% [markdown]
# # 🧪 Student Exercise – Desktop Vision Pipeline (EdgeAI Style)
#
# This notebook is a **guided exercise**.
#
# You will complete missing parts (marked as **TODO**) to build a real-time
# vision pipeline similar to what runs on embedded EdgeAI devices.
#
# ### Rules
# - Do NOT remove cells
# - Only edit code where TODO is indicated
# - Run cells from top to bottom

# %% [markdown]
# ## Step 0 – Imports
#
# All required libraries are imported here.
# If this cell fails, your environment is not set up correctly.

# %%
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output

print('Environment ready')

# %% [markdown]
# ## Step 1 – Open the Camera
#
# **TODO:** Open the default camera using OpenCV.
#
# Hint: use `cv2.VideoCapture(...)`

# %%
# TODO: open the default camera
cap = None

if cap is None or not cap.isOpened():
    raise RuntimeError('Camera not opened')

print('Camera opened')

# %% [markdown]
# ## Step 2 – Capture a Single Frame
#
# **TODO:** Capture exactly ONE frame from the camera.
#
# Hint: `ret, frame = cap.read()`

# %%
# TODO: read one frame
ret = False
frame = None

if not ret:
    raise RuntimeError('Failed to capture frame')

print('Frame shape:', frame.shape)

# %% [markdown]
# ## Step 3 – Display the Frame (Notebook-Safe)
#
# **TODO:** Convert the frame to RGB and display it inline.
#
# Hint: OpenCV uses BGR, Matplotlib uses RGB.

# %%
# TODO: convert BGR to RGB and display
frame_rgb = None

plt.imshow(frame_rgb)
plt.axis('off')
plt.title('Captured Frame')

# %% [markdown]
# ## Step 4 – Frame-by-Frame Processing Loop
#
# You will now create a **limited real-time loop**.
#
# **TODO:**
# - Capture frames
# - Convert to grayscale
# - Display result
# - Stop after 20 frames

# %%
# TODO: implement frame loop
for i in range(20):
    pass

# %% [markdown]
# ## Step 5 – Add Vision Processing (Edges)
#
# **TODO:** Replace grayscale with edge detection.
#
# Hint: `cv2.Canny()`

# %%
# TODO: edge detection loop
for i in range(20):
    pass

# %% [markdown]
# ## Step 6 – Add Frame-Rate Limiting (Embedded Constraint)
#
# Embedded cameras do not run at unlimited FPS.
#
# **TODO:**
# - Set a target FPS (e.g. 5)
# - Measure processing time
# - Sleep to enforce frame rate

# %%
# TODO: FPS-limited loop
TARGET_FPS = 5

for i in range(20):
    pass

# %% [markdown]
# ## Step 7 – Cleanup
#
# **TODO:** Release the camera properly.

# %%
# TODO: release camera
pass

print('Camera released')

# %% [markdown]
# ## ✅ What You Have Learned
#
# - How to acquire camera frames
# - How to process images frame-by-frame
# - How to enforce real-time constraints
# - How desktop vision maps to embedded EdgeAI systems
#
# This structure directly transfers to OpenMV and similar platforms.
